# %%
pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\asus\anaconda3\lib\site-packages (4.12.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\anaconda3\lib\site-packages (from BeautifulSoup4) (2.5)

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\asus\anaconda3\lib\site-packages (2.32.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asus\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\anaconda3\lib\site-packages (from requests) (2024.8.30)

# %%
from bs4 import BeautifulSoup
import requests
from urllib.parse import urljoin
import csv

base_url = 'https://books.toscrape.com/catalogue/page-{}.html'


with open('bookstoscrape.csv', 'w', newline='', encoding='utf-8') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(['Title', 'Price', 'Ratings', 'Genre'])  # Write header once

    for page in range(1, 21):
        url = base_url.format(page)
        source = requests.get(url)
        soup = BeautifulSoup(source.text, 'lxml')

        books = soup.find_all('li', class_='col-xs-6 col-sm-4 col-md-3 col-lg-3')

        for book in books:
            title = book.h3.a['title']
            price = book.find('p', class_='price_color').text.strip()

            rating_tag = book.find('p', class_='star-rating')
            rating_class = rating_tag['class'][1]
            rating_map = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}
            ratings = rating_map.get(rating_class, 0)

            
            relative_url = book.h3.a['href']
            book_url = urljoin('http://books.toscrape.com/catalogue/', relative_url)

           
            book_page = requests.get(book_url).text
            book_soup = BeautifulSoup(book_page, 'lxml')
            breadcrumb = book_soup.find('ul', class_='breadcrumb')
            genre = breadcrumb.find_all('li')[2].text.strip()

            
            csv_writer.writerow([title, price, ratings, genre])

            print(f"Page {page} scraped successfully.")
# Out:
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 1 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 2 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 3 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 4 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 5 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 6 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 7 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 8 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 9 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 10 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 11 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 12 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 13 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 14 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 15 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 16 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 17 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 18 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 19 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.
# Page 20 scraped successfully.

# %%
# cleaning the dataset
import pandas as pd
books_df = pd.read_csv('bookstoscrape.csv')
print(books_df.head(10))
# Out:
#                                                Title    Price  Ratings  \
# 0                               A Light in the Attic  Â£51.77        3
# 1                                 Tipping the Velvet  Â£53.74        1
# 2                                         Soumission  Â£50.10        1
# 3                                      Sharp Objects  Â£47.82        4
# 4              Sapiens: A Brief History of Humankind  Â£54.23        5
# 5                                    The Requiem Red  Â£22.65        1
# 6  The Dirty Little Secrets of Getting Your Dream...  Â£33.34        4
# 7  The Coming Woman: A Novel Based on the Life of...  Â£17.93        3
# 8  The Boys in the Boat: Nine Americans and Their...  Â£22.60        4
# 9                                    The Black Maria  Â£52.15        1
#
#                 Genre
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History
# 5         Young Adult
# 6            Business
# 7             Default
# 8             Default
# 9              Poetry

# %%
print(books_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    400 non-null    object
#  1   Price    400 non-null    object
#  2   Ratings  400 non-null    int64
#  3   Genre    400 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 12.6+ KB
# None

# %%
books_df['Price'] = books_df['Price'].str.replace(r'[^\d.]', '',regex=True).astype(float)

# %%
print(books_df['Price'].head(5))
# Out:
# 0    51.77
# 1    53.74
# 2    50.10
# 3    47.82
# 4    54.23
# Name: Price, dtype: float64

# %%
books_df.to_csv(r'D:\Downloads\all_cleaned_bookstoscrape_data.csv', index=False)
